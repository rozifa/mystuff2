# %% [markdown]
# # Modules, Classes, and Objects
#
# - Modules are like dictionaries in the way that they acces things-
# - There is a common pattern in Python where we take a key, value style pair and retrieve the value throught the key

# %%
mystuff = {'apple': "I AM APPLES!"}
print mystuff['apple']
# Out:
# I AM APPLES!

# %% [markdown]
# Suppose I create a module named mystuff.py

# %%
def apple():
    print "I AM APPLES"

# %%
# import mystuff

# %% [markdown]
# mystuff.apple( ) would calle the function apple from the module and print "I AM APPLES"

# %% [markdown]
# Even variables could be stored in the module:
#     tangerine = "memes"
#
# ...and this variable could be accesed from the module in the same way:
#     print mystuff.tangerine
